# %%
import json
import numpy as np
import imageio
import pdb
from pathlib import Path
import cv2
from PIL import Image

# @markdown The base directory for all captures. This can be anything if you're running this notebook on your own Jupyter runtime.
save_dir = './data/'  
capture_name = 'kubric_single_car_rand_v2_np'
# The root directory for this capture.
root_dir = Path(save_dir, capture_name)
# Where to save RGB images.
rgb_dir = root_dir / 'rgb'
rgb_raw_dir = root_dir / 'rgb-raw'
static_rgb_dir = root_dir / 'static-rgb'
static_rgb_raw_dir = root_dir / 'static-rgb-raw'
# Where to save mask images.
mask_dir = root_dir / 'mask'
mask_raw_dir = root_dir / 'mask-raw'
camera_gt_dir = root_dir / 'camera-gt'
camera_test_gt_dir = root_dir / 'camera-paths-gt' / 'orbit-mild'

camera_gt_dir.mkdir(exist_ok=True, parents=True)
camera_test_gt_dir.mkdir(exist_ok=True, parents=True)
if static_rgb_raw_dir.exists():
    static_rgb_dir.mkdir(exist_ok=True, parents=True)

# make dirs for freeze test if available
freeze_test_dir = root_dir / 'freeze-test'
if freeze_test_dir.exists():
    rgb_raw_freeze_test_dir = freeze_test_dir / 'rgb-raw'
    rgb_freeze_test_dir = freeze_test_dir / 'rgb'
    cam_freeze_test_dir = freeze_test_dir / 'camera-gt'

    rgb_freeze_test_dir.mkdir(exist_ok=True, parents=True)
    cam_freeze_test_dir.mkdir(exist_ok=True, parents=True)

    with open(freeze_test_dir / 'metadata_kubric.json','r') as f:
            k_freeze_meta = json.load(f)

with open(root_dir / 'metadata_kubric.json','r') as f:
    k_meta = json.load(f)

tmp_rgb_raw_dir = rgb_raw_dir

rgb_list = list(sorted(rgb_raw_dir.glob( '*.png')))
image_size = imageio.imread(rgb_list[0]).shape[:2]
rgb_list[:3]
# Out:
# [PosixPath('data/kubric_single_car_rand_v2_np/rgb-raw/rgba_00000.png'),
#  PosixPath('data/kubric_single_car_rand_v2_np/rgb-raw/rgba_00001.png'),
#  PosixPath('data/kubric_single_car_rand_v2_np/rgb-raw/rgba_00002.png')]

# %%
# @title Resize images into different scales.
# @markdown Here we save the input images at various resolutions (downsample by a factor of 1, 2, 4, 8). We use area relation interpolation to prevent moire artifacts.


def save_image(path, image: np.ndarray) -> None:
  print(f'Saving {path}')
  if not path.parent.exists():
    path.parent.mkdir(exist_ok=True, parents=True)
  with path.open('wb') as f:
    image = Image.fromarray(np.asarray(image))
    image.save(f, format=path.suffix.lstrip('.'))


def image_to_uint8(image: np.ndarray) -> np.ndarray:
  """Convert the image to a uint8 array."""
  if image.dtype == np.uint8:
    return image
  if not issubclass(image.dtype.type, np.floating):
    raise ValueError(
        f'Input image should be a floating type but is of type {image.dtype!r}')
  return (image * 255).clip(0.0, 255).astype(np.uint8)


def make_divisible(image: np.ndarray, divisor: int) -> np.ndarray:
  """Trim the image if not divisible by the divisor."""
  height, width = image.shape[:2]
  if height % divisor == 0 and width % divisor == 0:
    return image

  new_height = height - height % divisor
  new_width = width - width % divisor

  return image[:new_height, :new_width]


def downsample_image(image: np.ndarray, scale: int) -> np.ndarray:
  """Downsamples the image by an integer factor to prevent artifacts."""
  if scale == 1:
    return image

  height, width = image.shape[:2]
  if height % scale > 0 or width % scale > 0:
    raise ValueError(f'Image shape ({height},{width}) must be divisible by the'
                     f' scale ({scale}).')
  out_height, out_width = height // scale, width // scale
  resized = cv2.resize(image, (out_width, out_height), cv2.INTER_AREA)
  return resized



image_scales = "2"  # @param {type: "string"}
image_scales = [int(x) for x in image_scales.split(',')]

# %%
for image_path in Path(tmp_rgb_raw_dir).glob('*.png'):
  image = make_divisible(imageio.imread(image_path), max(image_scales))
  for scale in image_scales:
    save_image(
        rgb_dir / f'{scale}x/{image_path.stem}.png',
        image_to_uint8(downsample_image(image, scale)))

if mask_raw_dir.exists():
    for i, mask_path in enumerate(sorted(list(Path(mask_raw_dir).glob('*.png')))):
      mask = make_divisible(imageio.imread(mask_path), max(image_scales))
      for scale in image_scales:
        save_image(
            mask_dir / f"{scale}x/{rgb_list[i].stem.replace('segmentation','rgba')}.png",
            image_to_uint8(downsample_image(mask, scale)))


if freeze_test_dir.exists():
    for rgb_path in Path(rgb_raw_freeze_test_dir).glob('*.png'):
      image = make_divisible(imageio.imread(rgb_path), max(image_scales))
      for scale in image_scales:
        save_image(
            rgb_freeze_test_dir / f"{scale}x/{rgb_path.stem}.png",
            image_to_uint8(downsample_image(image, scale)))
# Out:
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00191.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00136.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00051.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00128.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00055.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00178.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00058.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00096.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00093.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00035.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00112.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00100.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00174.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00018.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00014.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00130.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00157.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00108.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00029.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00092.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00036.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00192.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00047.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00101.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00147.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00164.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00121.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00183.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00059.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00166.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00049.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00120.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00152.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00008.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00000.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00001.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00069.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00110.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00167.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00109.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00033.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00163.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00004.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00125.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00026.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00177.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00123.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00039.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00145.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00181.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00105.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00161.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00057.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00088.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00022.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00194.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00081.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00133.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00045.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00195.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00021.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00172.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00158.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00144.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00176.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00005.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00028.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00159.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00052.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00095.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00041.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00141.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00073.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00031.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00025.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00188.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00179.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00083.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00065.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00129.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00037.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00199.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00020.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00150.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00113.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00007.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00103.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00184.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00006.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00003.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00060.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00098.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00197.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00040.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00094.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00169.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00106.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00134.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00132.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00084.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00013.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00089.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00068.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00054.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00127.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00182.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00124.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00102.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00104.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00198.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00117.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00056.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00149.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00165.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00162.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00155.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00048.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00131.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00038.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00010.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00067.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00153.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00034.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00126.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00186.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00146.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00111.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00072.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00193.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00160.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00030.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00175.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00138.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00024.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00171.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00116.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00066.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00019.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00016.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00053.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00012.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00170.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00185.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00080.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00099.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00074.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00143.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00079.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00063.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00180.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00023.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00085.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00071.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00015.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00082.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00046.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00043.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00140.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00017.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00062.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00114.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00148.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00189.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00061.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00168.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00122.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00087.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00076.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00070.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00050.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00090.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00077.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00139.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00142.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00135.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00009.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00002.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00107.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00091.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00027.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00115.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00086.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00154.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00137.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00032.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00064.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00187.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00151.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00119.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00097.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00118.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00075.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00173.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00044.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00078.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00011.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00190.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00042.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00196.png
# Saving data/kubric_single_car_rand_v2_np/rgb/2x/rgba_00156.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00000.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00001.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00002.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00003.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00004.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00005.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00006.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00007.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00008.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00009.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00010.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00011.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00012.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00013.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00014.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00015.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00016.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00017.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00018.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00019.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00020.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00021.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00022.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00023.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00024.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00025.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00026.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00027.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00028.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00029.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00030.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00031.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00032.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00033.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00034.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00035.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00036.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00037.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00038.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00039.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00040.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00041.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00042.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00043.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00044.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00045.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00046.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00047.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00048.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00049.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00050.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00051.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00052.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00053.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00054.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00055.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00056.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00057.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00058.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00059.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00060.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00061.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00062.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00063.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00064.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00065.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00066.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00067.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00068.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00069.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00070.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00071.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00072.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00073.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00074.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00075.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00076.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00077.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00078.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00079.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00080.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00081.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00082.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00083.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00084.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00085.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00086.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00087.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00088.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00089.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00090.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00091.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00092.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00093.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00094.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00095.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00096.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00097.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00098.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00099.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00100.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00101.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00102.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00103.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00104.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00105.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00106.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00107.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00108.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00109.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00110.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00111.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00112.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00113.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00114.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00115.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00116.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00117.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00118.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00119.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00120.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00121.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00122.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00123.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00124.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00125.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00126.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00127.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00128.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00129.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00130.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00131.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00132.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00133.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00134.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00135.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00136.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00137.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00138.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00139.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00140.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00141.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00142.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00143.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00144.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00145.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00146.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00147.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00148.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00149.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00150.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00151.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00152.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00153.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00154.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00155.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00156.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00157.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00158.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00159.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00160.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00161.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00162.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00163.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00164.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00165.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00166.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00167.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00168.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00169.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00170.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00171.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00172.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00173.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00174.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00175.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00176.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00177.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00178.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00179.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00180.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00181.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00182.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00183.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00184.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00185.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00186.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00187.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00188.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00189.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00190.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00191.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00192.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00193.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00194.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00195.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00196.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00197.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00198.png
# Saving data/kubric_single_car_rand_v2_np/mask/2x/rgba_00199.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00051.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00055.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00058.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00096.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00093.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00035.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00018.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00014.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00029.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00092.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00036.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00047.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00059.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00049.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00008.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00000.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00001.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00069.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00033.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00004.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00026.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00039.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00057.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00088.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00022.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00081.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00045.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00021.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00005.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00028.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00052.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00095.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00041.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00073.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00031.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00025.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00083.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00065.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00037.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00020.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00007.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00006.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00003.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00060.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00098.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00040.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00094.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00084.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00013.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00089.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00068.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00054.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00056.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00048.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00038.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00010.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00067.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00034.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00072.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00030.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00024.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00066.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00019.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00016.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00053.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00012.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00080.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00099.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00074.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00079.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00063.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00023.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00085.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00071.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00015.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00082.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00046.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00043.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00017.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00062.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00061.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00087.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00076.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00070.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00050.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00090.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00077.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00009.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00002.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00091.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00027.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00086.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00032.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00064.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00097.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00075.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00044.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00078.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00011.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/rgb/2x/rgba_00042.png

# %%
if static_rgb_raw_dir.exists():
    for rgb_path in Path(static_rgb_raw_dir).glob('*.png'):
      image = make_divisible(imageio.imread(rgb_path), max(image_scales))
      for scale in image_scales:
        save_image(
            static_rgb_dir / f"{scale}x/{rgb_path.stem}.png",
            image_to_uint8(downsample_image(image, scale)))
            
if freeze_test_dir.exists() and (freeze_test_dir / 'static-rgb-raw').exists():
  (freeze_test_dir / 'static-rgb').mkdir(exist_ok=True, parents=True)
  for rgb_path in Path(freeze_test_dir / 'static-rgb-raw').glob('*.png'):
    image = make_divisible(imageio.imread(rgb_path), max(image_scales))
    for scale in image_scales:
      save_image(
          (freeze_test_dir / 'static-rgb') / f"{scale}x/{rgb_path.stem}.png",
          image_to_uint8(downsample_image(image, scale)))
# Out:
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00191.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00136.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00051.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00128.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00055.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00178.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00058.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00096.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00093.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00035.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00112.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00100.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00174.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00018.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00014.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00130.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00157.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00108.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00029.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00092.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00036.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00192.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00047.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00101.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00147.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00164.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00121.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00183.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00059.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00166.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00049.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00120.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00152.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00008.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00000.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00001.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00069.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00110.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00167.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00109.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00033.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00163.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00004.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00125.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00026.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00177.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00123.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00039.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00145.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00181.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00105.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00161.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00057.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00088.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00022.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00194.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00081.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00133.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00045.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00195.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00021.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00172.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00158.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00144.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00176.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00005.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00028.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00159.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00052.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00095.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00041.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00141.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00073.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00031.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00025.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00188.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00179.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00083.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00065.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00129.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00037.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00199.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00020.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00150.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00113.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00007.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00103.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00184.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00006.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00003.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00060.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00098.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00197.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00040.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00094.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00169.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00106.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00134.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00132.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00084.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00013.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00089.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00068.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00054.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00127.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00182.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00124.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00102.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00104.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00198.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00117.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00056.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00149.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00165.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00162.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00155.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00048.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00131.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00038.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00010.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00067.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00153.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00034.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00126.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00186.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00146.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00111.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00072.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00193.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00160.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00030.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00175.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00138.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00024.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00171.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00116.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00066.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00019.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00016.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00053.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00012.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00170.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00185.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00080.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00099.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00074.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00143.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00079.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00063.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00180.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00023.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00085.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00071.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00015.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00082.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00046.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00043.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00140.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00017.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00062.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00114.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00148.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00189.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00061.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00168.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00122.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00087.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00076.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00070.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00050.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00090.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00077.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00139.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00142.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00135.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00009.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00002.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00107.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00091.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00027.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00115.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00086.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00154.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00137.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00032.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00064.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00187.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00151.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00119.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00097.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00118.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00075.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00173.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00044.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00078.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00011.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00190.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00042.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00196.png
# Saving data/kubric_single_car_rand_v2_np/static-rgb/2x/rgba_00156.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00051.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00055.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00058.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00096.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00093.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00035.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00018.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00014.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00029.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00092.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00036.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00047.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00059.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00049.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00008.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00000.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00001.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00069.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00033.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00004.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00026.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00039.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00057.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00088.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00022.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00081.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00045.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00021.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00005.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00028.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00052.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00095.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00041.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00073.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00031.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00025.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00083.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00065.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00037.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00020.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00007.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00006.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00003.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00060.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00098.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00040.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00094.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00084.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00013.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00089.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00068.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00054.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00056.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00048.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00038.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00010.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00067.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00034.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00072.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00030.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00024.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00066.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00019.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00016.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00053.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00012.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00080.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00099.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00074.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00079.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00063.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00023.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00085.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00071.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00015.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00082.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00046.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00043.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00017.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00062.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00061.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00087.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00076.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00070.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00050.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00090.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00077.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00009.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00002.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00091.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00027.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00086.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00032.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00064.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00097.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00075.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00044.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00078.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00011.png
# Saving data/kubric_single_car_rand_v2_np/freeze-test/static-rgb/2x/rgba_00042.png

# %% [markdown]
# Check the generated image:

# %%
image_paths = list((rgb_dir / '1x').iterdir())
Image.open(image_paths[0])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x512 at 0x2B93D535ADC0>

# %% [markdown]
# ## Write ground truth camera

# %%
from scipy.spatial.transform import Rotation as R

cameras = []

for i, rgb in enumerate(rgb_list):
    meta = {}
    quat = k_meta['camera']['quaternions'][i]
    # change quaternion format from [w,x,y,z] to [x,y,z,w]
    quat = [quat[1],quat[2],quat[3],quat[0]]
    rot = R.from_quat(quat)
    # orientation is the world to camera rotation matrix!!!
    matrix = rot.as_matrix()
    # rotate camera -- seems to be needed for some reason
    # matrix = matrix @ np.array([[ 1, 0, 0],
    #                             [ 0,-1, 0],
    #                             [ 0, 0,-1]])
    meta['orientation'] = matrix.T.tolist()
    meta['position'] = k_meta['camera']['positions'][i]
    meta['focal_length'] = k_meta['camera']['focal_length'] * image_size[0] / k_meta['camera']['sensor_width']  # k_meta['camera']['focal_length']  # 428.4225158691406  
    meta['principal_point'] = [image_size[0]/2, image_size[1]/2] # check
    meta['skew'] = 0.
    meta['pixel_aspect_ratio'] = 1. # check
    meta['radial_distortion'] = [0., 0., 0.] # check
    meta['tangential_distortion'] = [0., 0.] # check
    meta['image_size'] = image_size
    cameras.append(meta)

    with open(str(camera_gt_dir / rgb.stem) + '.json', 'w') as f:
        json.dump(meta, f, indent=2)

# write freeze test cameras
if freeze_test_dir.exists():
    for i, rgb in enumerate(list(sorted(rgb_raw_freeze_test_dir.glob('*.png')))):
        meta = {}
        quat = k_freeze_meta['camera']['quaternions'][i]
        # change quaternion format from [w,x,y,z] to [x,y,z,w]
        quat = [quat[1],quat[2],quat[3],quat[0]]
        rot = R.from_quat(quat)
        matrix = rot.as_matrix()
        # rotate camera -- seems to be needed for some reason
        # matrix = matrix @ np.array([[ 1, 0, 0],
        #                             [ 0,-1, 0],
        #                             [ 0, 0,-1]])
        meta['orientation'] = matrix.T.tolist()
        meta['position'] = k_freeze_meta['camera']['positions'][i]
        meta['focal_length'] = k_freeze_meta['camera']['focal_length'] * image_size[0] / k_freeze_meta['camera']['sensor_width'] 
        meta['principal_point'] = [image_size[0]/2, image_size[1]/2] # check
        meta['skew'] = 0.
        meta['pixel_aspect_ratio'] = 1. # check
        meta['radial_distortion'] = [0., 0., 0.] # check
        meta['tangential_distortion'] = [0., 0.] # check
        meta['image_size'] = image_size

        with open(str(cam_freeze_test_dir / rgb.stem) + '.json', 'w') as f:
            json.dump(meta, f, indent=2)

# %% [markdown]
# # Write test camera

# %%
from hypernerf import camera as camera_model
# compute center point of all cameras
positions = np.array([cam['position'] for cam in cameras])
center = np.average(positions, axis=0)
center_axis = (0. - center) / np.linalg.norm(center)
axis_2 = center_axis.copy()
axis_2[0] += 1
axis_a = np.cross(center_axis, axis_2)
axis_a = axis_a / np.linalg.norm(axis_a)
axis_b = np.cross(center_axis, axis_a)
axis_b = axis_b / np.linalg.norm(axis_b)

# radius ratio decides the circle radius of test camera
RADIUS_RATIO = 0.5
N_TEST = 100

dists = []
for cam in cameras:
    dists.append(np.sqrt(np.sum((np.array(cam['position']) - center) ** 2)))
mean_dist = np.average(dists)
radius = mean_dist * RADIUS_RATIO
print(f'radius: {radius}')

angles = np.linspace(0, 2 * np.pi, N_TEST)
for i, ang in enumerate(angles):  
    new_pos = center + radius * np.cos(ang) * axis_a + radius * np.sin(ang) * axis_b

    test_cam = camera_model.Camera.from_json(str(camera_gt_dir / rgb_list[0].stem) + '.json')
    test_cam.position = new_pos
    test_cam.look_at(new_pos, np.array([0,0,0]), np.array([1,0,0]))

    with open(str(camera_test_gt_dir / f'{i:06d}.json'), 'w') as f:
        json.dump(test_cam.to_json(), f, indent=2)
# Out:
# radius: 1.065220818188704

# %% [markdown]
# ## Write dataset split

# %%
# @title Save dataset split to `dataset.json`.

VAL_RATIO = 0

all_ids = list(map(lambda x: x.stem,rgb_list))
val_ids = all_ids[::int(1 / VAL_RATIO)] if VAL_RATIO > 0 else []
train_ids = sorted(set(all_ids) - set(val_ids))

print(f'Num of train: {len(train_ids)}')
print(f'Num of val: {len(val_ids)}')

dataset_json = {
    'count': len(all_ids),
    'num_exemplars': len(train_ids),
    'ids': all_ids,
    'train_ids': train_ids,
    'val_ids': val_ids,
}

dataset_json_path = root_dir / 'dataset.json'
with dataset_json_path.open('w') as f:
    json.dump(dataset_json, f, indent=2)

print(f'Saved dataset information to {dataset_json_path}')

# write meta info for freeze test if exists
if freeze_test_dir.exists():
    all_ids_freeze_test = [img.stem for img in list(sorted(rgb_raw_freeze_test_dir.glob('*.png')))]
    train_ids_freeze_test = []
    val_ids_freeze_test = all_ids_freeze_test
    dataset_json = {
        'count': len(all_ids_freeze_test),
        'num_exemplars': len(train_ids_freeze_test),
        'ids': all_ids_freeze_test,
        'train_ids': train_ids_freeze_test,
        'val_ids': val_ids_freeze_test,
    }

    dataset_json_path = freeze_test_dir / 'dataset.json'
    with dataset_json_path.open('w') as f:
        json.dump(dataset_json, f, indent=2)
# Out:
# Num of train: 200
# Num of val: 0
# Saved dataset information to data/kubric_single_car_rand_v2_np/dataset.json

# %% [markdown]
# ## Save metadata info

# %%
# @title Save metadata information to `metadata.json`.
import bisect

metadata_json = {}
for i, image_id in enumerate(train_ids):
  metadata_json[image_id] = {
      'warp_id': i,
      'appearance_id': i,
      'camera_id': 0,
  }
for i, image_id in enumerate(val_ids):
  i = bisect.bisect_left(train_ids, image_id)
  metadata_json[image_id] = {
      'warp_id': i,
      'appearance_id': i,
      'camera_id': 0,
  }

metadata_json_path = root_dir / 'metadata.json'
with metadata_json_path.open('w') as f:
    json.dump(metadata_json, f, indent=2)

print(f'Saved metadata information to {metadata_json_path}')


# write meta info for freeze test if exists
if freeze_test_dir.exists():
  freeze_frame = metadata_json[list(sorted(rgb_raw_freeze_test_dir.glob('*.png')))[k_freeze_meta['test_freeze_frame'] - 1].stem]
  # freeze_frame = metadata_json[list(sorted(rgb_raw_freeze_test_dir.glob('*.png')))[k_freeze_meta['test_freeze_frame']].stem]

  metadata_freeze_json = {}
  for i, image_path in enumerate(list(sorted(rgb_raw_freeze_test_dir.glob('*.png')))):
    image_id = image_path.stem
    metadata_freeze_json[image_id] = freeze_frame

  metadata_json_path = freeze_test_dir / 'metadata.json'
  with metadata_json_path.open('w') as f:
      json.dump(metadata_freeze_json, f, indent=2)

  print(f'Saved freeze metadata information to {metadata_json_path}')
# Out:
# Saved metadata information to data/kubric_single_car_rand_v2_np/metadata.json
# Saved freeze metadata information to data/kubric_single_car_rand_v2_np/freeze-test/metadata.json

# %%
Path('data/kubric_soft/freeze-test/static-rgb-raw')
# Out:
# PosixPath('data/kubric_soft/freeze-test/static-rgb-raw')

# %%
rgb_raw_freeze_test_dir
# Out:
# PosixPath('data/kubric_single_car_rand_v2_np/freeze-test/rgb-raw')

# %% [markdown]
# ## Write scene info

# %%
def get_bbox_corners(points):
  lower = points.min(axis=0)
  upper = points.max(axis=0)
  return np.stack([lower, upper])

bbox_corners = get_bbox_corners(np.array(k_meta['instances'][0]['bboxes_3d'])[0])
bbox_corners = np.array([[0,   0,  0],
                         [50, 50, 10]])

# scene_center = np.mean(bbox_corners, axis=0)
scene_scale = 1.0 / np.sqrt(np.sum((bbox_corners[1] - bbox_corners[0]) ** 2))
scene_center = np.array([0., 0., 0.])
# scene_scale = 0.01

print(f'Scene Center: {scene_center}')
print(f'Scene Scale: {scene_scale}')

# @title Save scene information to `scene.json`.

scene_json_path = root_dir /  'scene_gt.json'
with scene_json_path.open('w') as f:
  json.dump({
      'scale': scene_scale,
      'center': scene_center.tolist(),
      'bbox': bbox_corners.tolist(),
      'near': 0.1,
      'far': 1. # bbox_corners[1].max() * scene_scale,
  }, f, indent=2)

print(f'Saved scene information to {scene_json_path}')
# Out:
# Scene Center: [0. 0. 0.]
# Scene Scale: 0.0140028008402801
# Saved scene information to data/kubric_single_car_rand_v2_np/scene_gt.json
